# %%
import datetime
import json
import logging
import requests
import tkinter as tk
import urllib
from typing import List, Dict, Any
from classes import Settings, Logger
config = Settings.WEATHER

# %%
l = Logger(__name__, Settings.LOGGER)

# %%
l.debug("test")
l.info("test")
l.warning("test")
l.error("test")
l.critical("test")
# Out:
# 2021-06-05 21:35:26,386 - INFO - __main__ - test
# 2021-06-05 21:35:26,394 - WARNING - __main__ - test
# 2021-06-05 21:35:26,395 - ERROR - __main__ - test
# 2021-06-05 21:35:26,395 - CRITICAL - __main__ - test
